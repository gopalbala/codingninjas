# %%
def power(x,y):
    if y == 0:
        return 1
    pr = power(x,y//2)
    if y % 2 == 0:
        return pr * pr
    else:
        return x * pr * pr
x, y = [int(x) for x in input().split()]
print(power(x,y))
# Out:
# 2 5
# 32
