# %%
def czeros(n):
    if n == 0:
        return 0
    if n > 0:
        if n % 10 == 0:
            return czeros(n//10) + 1
        else:
            return czeros(n//10)
n = int(input())
print(czeros(n))
# Out:
# 10204
# 2
