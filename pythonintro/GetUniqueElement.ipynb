# %%
def getunique(list):
    y = 0
    for i in range(0,len(list)):
        y = y ^ list[i]
    return y

size = int(input())
list = [int(i) for i in input().split()]
y = getunique(list)
print(y)
# Out:
# 2 3 1 6 3 6 2
# 1
