# %%
def fib(n):
    n1 =1
    n2 = 1
    i = 3
    n3 = 0
    while(i<=n):
        n3 = n1 + n2
        n1 = n2
        n2 = n3
        i = i + 1
    return n3

n = int(input())
print(fib(n))
# Out:
# 4
# 3
