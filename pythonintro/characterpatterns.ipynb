# %%
n = int(input())
i = 1
num = 65
while i<= n:
    j = 1
    while j <= i:
        ch = chr(num)
        print(ch, end=" ")
        j = j + 1
    num = num + 1
    i = i + 1
    print()
# Out:
# 4
# A
# B B
# C C C
# D D D D
